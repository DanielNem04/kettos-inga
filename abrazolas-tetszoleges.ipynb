# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

def abrazolo(l1=1, l2=0.5, m1=1, m2=1, phi1=3.14, phi2=3.14, o1=0, o2=0, T=100, h=0.001):
    os.system(f"./build/my_program {l1} {l2} {m1} {m2} {phi1} {phi2} {o1} {o2} {T} {h}")
    print(os.system("pwd"))
    df = pd.read_csv("double_pendulum_output.csv")
    # 1. inga fázistere
    plt.figure(figsize=(10, 6))
    plt.plot(df['phi1'], df['omega1'], color='blue')
    plt.xlabel(rf'$\varphi_1$ (rad)', fontsize=14)
    plt.ylabel(rf'$\omega_1$ (rad/s)', fontsize=14)
    plt.title(rf'Fázistér: $\varphi_1$ vs $\omega_1$', fontsize=16)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # 2. inga fázistere
    plt.figure(figsize=(8, 6))
    plt.plot(df['phi2'], df['omega2'], color='red')
    plt.xlabel(rf'$\varphi_2$ (rad)', fontsize=14)
    plt.ylabel(rf'$\omega_2$ (rad/s)', fontsize=14)
    plt.title(rf'Fázistér: $\varphi_2$ vs $\omega_2$', fontsize=16)
    plt.grid(True)
    plt.tight_layout()
    plt.show()


    plt.figure(figsize=(8, 6))
    plt.plot(df['x1'], df['y1'], label=r'1. inga pályája', color='blue')
    plt.plot(df['x2'], df['y2'], label=r'2. inga pályája', color='red')

    plt.xlabel(r'$x$ (m)', fontsize=14)
    plt.ylabel(r'$y$ (m)', fontsize=14)
    plt.title(r'Kettős inga pályagörbéi az $x$-$y$ síkban', fontsize=16)

    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.axis('equal')  # hogy jobban lássuk, arányosan
    plt.show()
    pass

# %%
abrazolo()
# Out:
# Eredmények elmentve a double_pendulum_output.csv fájlba.
# /Users/nemeskeridaniel/kettos-inga
# 0
